# %% [markdown]
# # **Berikut adalah code untuk mengubah FOTO yang memilliki TEKS di dalamnya menjadi TEKS**

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# ...

# %%
from PIL import Image
import pytesseract

# Tentukan lokasi Tesseract OCR
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# %%
from google.colab import files

# Unggah gambar
uploaded = files.upload()

# Ambil nama file gambar
image_path = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-da4e5d30-3be1-4a61-affc-6d4543ffea0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da4e5d30-3be1-4a61-affc-6d4543ffea0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Baca gambar
image = Image.open(image_path)

# Konversi gambar ke teks menggunakan Tesseract OCR
text = pytesseract.image_to_string(image)

# Tampilkan hasil deteksi tulisan
print("Hasil Deteksi Tulisan:")
print(text)
# Out:
# Hasil Deteksi Tulisan:
# Be eset Re oS Ue neue Lee Ue era
# desa yang indah, tinggalah seekor kucing bernama Whisker. Whisker adalah
# kucing yang cerdik dan penuh dengan keingintahuan. Setiap hari, Whisker akan
# menjelajahi hutan di sekitar desa, bertemu dengan berbagai makhluk ajaib, dan
#
# Deane ciate N CURT Run cues
#
# re UR Ts cm Cue een cucu Renet ecru)
# Re TD ec cep Ree Curae
# Rene ee Neue oa eee eeu eT)
#
# Ce A east eRe cues
#
# Mire eg Un ete eee Re ec P oc
# Pees Ca ae cig ete ces De
# COU mun Come Eee cueing ae el
# eect
#
# Di dalam gua, Whisker terkejut menemui seekor naga besar yang tengah duduk
# Ceca eet tat cunt eon a et)
# Dee Un Ce UCase Un
#
# Namun, Whisker segera merasa lega ketika naga itu tersenyum lembut. Naga
# Reeser ecu Cie eaten eee
# fa ee SS eee NY mea een
# Pee et Aan auc cn eee ecu R ETE
# yang tersembunyi di dalam hutan.

# %% [markdown]
# # **Berikut adalah code untuk mengubah TEKS menjadi SUARA**

# %%
# !sudo apt-get install espeak
# !pip install pyttsx3
# !pip install pydub
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,382 kB of archives.
# After this operation, 3,178 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudio2 amd64 19.6.0-1.1 [65.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsonic0 amd64 0.2.0-11build1 [10.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak-data amd64 1.48.15+dfsg-3 [1,085 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak1 amd64 1.48.15+dfsg-3 [156 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak amd64 1.48.15+dfsg-3 [64.2 kB]
# ...

# %%
import pyttsx3
from pydub import AudioSegment
from pydub.playback import play
import os

def text_to_speech(text, output_file):
    engine = pyttsx3.init()

    voices = engine.getProperty('voices')
    i = 0
    for voice in voices:
      print(i," ID:", voice.id, "Name:", voice.name, "Lang:", voice.languages)
      i = i+1
    engine.setProperty('voice', voices[39].id)

    rate = engine.getProperty('rate')
    engine.setProperty('rate', 130)

    engine.save_to_file(text, output_file)
    #engine.runAndWait()

def convert_to_mp3(input_file, output_file):
    sound = AudioSegment.from_wav(input_file)
    sound.export(output_file, format="mp3")

if __name__ == "__main__":
    teks = "Halo, selamat datang di dunia Text-to-Speech menggunakan Python!"

    # Membuat direktori output jika belum ada
    if not os.path.exists("output"):
        os.makedirs("output")

    # Menentukan path file output WAV dan MP3
    wav_output_file = "output/output.wav"
    mp3_output_file = "output/output.mp3"

    # Mengubah teks menjadi suara dan menyimpannya sebagai file WAV
    text_to_speech(text, wav_output_file)
    files.download(wav_output_file)
    # Mengonversi file WAV menjadi MP3
    #convert_to_mp3(wav_output_file, mp3_output_file)

    print(f"Suara disimpan dalam file: {mp3_output_file}")
# Out:
# 0  ID: afrikaans Name: afrikaans Lang: [b'\x05af']
# 1  ID: aragonese Name: aragonese Lang: [b'\x05an']
# 2  ID: bulgarian Name: bulgarian Lang: [b'\x05bg']
# 3  ID: bengali Name: bengali Lang: [b'\x05bn']
# 4  ID: bosnian Name: bosnian Lang: [b'\x05bs']
# 5  ID: catalan Name: catalan Lang: [b'\x05ca']
# 6  ID: czech Name: czech Lang: [b'\x05cs']
# 7  ID: welsh Name: welsh Lang: [b'\x05cy']
# 8  ID: danish Name: danish Lang: [b'\x05da']
# 9  ID: german Name: german Lang: [b'\x05de']
# 10  ID: greek Name: greek Lang: [b'\x05el']
# 11  ID: default Name: default Lang: [b'\x05en']
# 12  ID: english Name: english Lang: [b'\x02en-gb']
# 13  ID: en-scottish Name: en-scottish Lang: [b'\x05en-sc']
# 14  ID: english-north Name: english-north Lang: [b'\x05en-uk-north']
# 15  ID: english_rp Name: english_rp Lang: [b'\x05en-uk-rp']
# 16  ID: english_wmids Name: english_wmids Lang: [b'\x05en-uk-wmids']
# 17  ID: english-us Name: english-us Lang: [b'\x02en-us']
# ...
